# %%
import numpy as np
import matplotlib.pyplot as plt
from turb.lesgo_utils import lesgo_data, read_array_from_file, write_array_to_file
import pyutils.plot_utils as plt_utils



from datetime import datetime
date_marker = datetime.today().strftime('%Y_%m_%d')

# %%
root_dir = '/home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff'

dims = [128, 128, 64]
domain = [2*np.pi, np.pi, 1]
ntheta = 3

ldata = lesgo_data(domain, dims, root_dir, ntheta=3)

# t_total = 1
# tstep = 1
# tt = np.arange(0, t_total+1, tstep)

# %% [markdown]
# ## Temperature Diffusion Setup
#
# ### Initial and boundary conditions
# The setup of initial and boundary conditions in the original paper are
# $$
# \begin{aligned}
# &\theta_i (x, y, z, 0) = 0.5(1-y^2)\\
# & \theta_i (x, -1, z, t) = 0, \quad \theta_i (x, 1, z, t) = 0
# \end{aligned}
# $$ (theoretical_T)

# %% [markdown]
# However, in LESGO, the normal direction is $z$ instead of $y$ and the simulation is running on a half channel. So that the transformed IC and BCs are
# $$
# \begin{aligned}
# &\theta_i (x, \hat{y}, \hat{z}, 0) = 0.5(2\hat{z} - \hat{z}^2 )\\
# & \theta_i (x, \hat{y}, \hat{z}=0, t) = 0, \quad \frac{\partial \theta_i}{\partial \hat{z}} (x, \hat{y}, \hat{z}=1, t) = 0
# \end{aligned}
# $$
# which is based on
# $$
# \hat{z} = y+1,\quad \forall y \in [-1, 0] \quad \& \quad \hat{y} = z, \quad\forall z \in [0, \pi].
# $$

# %%
Pr_list = [0.1, 0.71, 2]
Re = 180
RePr = Re*np.array(Pr_list)

# %% [markdown]
# ## Source
#
# According to Kim's work{cite}`kimTransportPassiveScalars1989`, they also has a continuous source term inside the channel,
# $$
# \begin{equation}
# Q_i = \frac{2}{\text{Re}\text{Pr}_i}.
# \end{equation}
# $$

# %%
# Read template config
# ldata._read_lesgoconf('/home/zyou6474/Projects/lesgo_eri/src/lesgo.conf')
ldata._read_conf('/home/zyou6474/Projects/ERI/notebooks/cases/heat_transfer/configs/config_Kims_abbr_debug_2023_07_22.ini')


# Read previous velocity field as Initial Condition
ldata.read_inputs('/home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/inputs/turbulence_128_128_64')


# Use parabolic velocity profile as IC
xc, yc, zc = ldata.coords
xx, yy, zz = np.meshgrid(xc, yc, zc, indexing='ij')
theta = 0.5 * (2*zz - zz**2)

# Create single wavenumber theta in each layer as Initial Condition
thetaic_shape = dims*1
thetaic_shape.insert(0, ntheta)
thetaic_shape = tuple(thetaic_shape)
ldata.data['theta_ic'] = np.empty(shape = thetaic_shape) 
for k in range(ntheta):
    ldata.data['theta_ic'][k] = theta
    
    
source = []

for Pr in Pr_list:
    source.append(zz*0 + 2/Re/Pr)
    print('%.4f amount of scalar is generated at each point' % (2/Re/Pr))

ldata.config['SCALAR']['source_opt'] = '1'

ldata.data['source'] = np.empty(shape = thetaic_shape) 
for k in range(ntheta):
    ldata.data['source'][k] = source[k]

# Switch off Scalar source
ldata._fnames(fmt_ntheta='%.3i')
ldata._write_conf('/home/zyou6474/Projects/ERI/notebooks/cases/heat_transfer/configs/config_Kims_abbr_debug_%s.ini' % date_marker)
ldata.write_inputs()
# Out:
# 0.1111 amount of scalar is generated at each point
# 0.0156 amount of scalar is generated at each point
# 0.0056 amount of scalar is generated at each point
# Configs is written in /home/zyou6474/Projects/ERI/notebooks/cases/heat_transfer/configs/config_Kims_abbr_debug_2023_07_23.ini
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/u_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/v_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/w_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/theta.001.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/theta.002.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/theta.003.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/source.001
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/source.002
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/source.003
# Write configs in /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/inputs/lesgo.conf

# %%
t_total = int(ldata.config['TIME']['nsteps'])
tstep = int(ldata.config['OUTPUT']['dtstep'])
tt = np.arange(0, t_total+1, tstep)

# %% [markdown]
# ## Animation

# %%
fig_dir = r'/home/zyou6474/Projects/ERI/notebooks/figures'


job_mark = '56_validation_diff_'
k_ind = 1
var_ind = 'theta'

plt_utils.generate_gif(tt, ldata, fig_dir, var_ind, k_ind, job_mark+date_marker, vmin=0, vmax=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 8
#       5 k_ind = 1
#       6 var_ind = 'theta'
# ----> 8 plt_utils.generate_gif(tt, ldata, fig_dir, var_ind, k_ind, job_mark+date_marker, vmin=0, vmax=1)
#
# File ~/.venv/lib/python3.10/site-packages/python_utils-0.1.0-py3.10.egg/pyutils/plot_utils.py:14, in generate_gif(timestep, ldata, fig_dir, var, k, marker, **fig_args)
#      12 filenames = []
#      13 for i in timestep:
# ---> 14     ldata.read_data(i)
#      15     fig, ax = contour_channel(ldata.coords, ldata.data[var][k], **fig_args)
#      17     # create file name and append it to a list
#
# File ~/.venv/lib/python3.10/site-packages/python_utils-0.1.0-py3.10.egg/turb/lesgo_utils.py:203, in lesgo_data.read_data(self, t_ind)
#     202 def read_data(self, t_ind):
# --> 203     self.read_velocity(t_ind)
#     204     self.read_scalar(t_ind)
#     206     return
#
# File ~/.venv/lib/python3.10/site-packages/python_utils-0.1.0-py3.10.egg/turb/lesgo_utils.py:209, in lesgo_data.read_velocity(self, t_ind, f)
#     208 def read_velocity(self, t_ind, f=None):
# --> 209     u = read_array_from_file(self.u_f % t_ind, self.dims)
#     210     v = read_array_from_file(self.v_f % t_ind, self.dims)
#     211     w = read_array_from_file(self.w_f % t_ind, self.dims)
#
# File ~/.venv/lib/python3.10/site-packages/python_utils-0.1.0-py3.10.egg/turb/lesgo_utils.py:55, in read_array_from_file(filename, shape, dtype)
#      46 def read_array_from_file(filename, shape, dtype=np.float64):
#      47     """
#      48     Read the flattened array from the binary file
#      49     Parameters:
#    (...)
#      53         array    : Numpy array with shape [nx, ny, nz] read from binary file.
#      54     """
# ---> 55     with open(filename, "rb") as f:
#      56         array_column_major = np.fromfile(f, dtype=dtype)
#      58     # Reshape the array into its original shape
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/56_validation_diff/output/velocity/u_velocity.00000002'

# %% [markdown]
# ## Stability check
#
# Plot friction Reynolds number $Re_{\tau}$ in time series to check if the simulation is stabilized,
# $$
# Re_{\tau} = \frac{u_{\tau}\delta}{\nu} = \frac{\delta}{\delta_{\nu}},
# $$
# which is determined by the characteristic velocity scale -- friction velocity $u_{\tau} = \sqrt{\frac{\tau_{w}}{\rho}}$ and characteristic length scale -- viscous length scale $\delta_{\nu} = \frac{\nu}{u_{\tau}}$. [^wall_shear_stress]
#
# [^wall_shear_stress]: Wall shear stress $\tau_w = \rho\nu \left( \frac{\mathrm{d} \langle U\rangle}{\mathrm{d} y} \right)_{y=0}$ .
#
# In our setting, the characteristic velocity scale $u_{\tau}=1m/s$ (u_star in `lesgo.conf`), characteristic length scale $\delta= 1m$ (z_i in `lesgo.conf`) and molecular viscosity $\nu = 0.00556 m^2/s$ (nu_molec in `lesgo.conf`).

# %%
u_tau = 1
z_i = 1
nu = 0.00556

# %% [markdown]
# Since LESGO's streamwise velocity is located at center of uv-grid, so that we calculate the velocity gradient by
# $$
# \left( \frac{\mathrm{d} \langle U\rangle}{\mathrm{d} y} \right)_{y=0} = U_{k=1} / z_{k=1}
# $$

# %%
# Check Re_tau
Re_tau = []
for t_ind, t in enumerate(tt):
    ldata.read_data(t)
    u_average = np.average(ldata.data['u'], axis = (0, 1))
    u_tau_actual = np.sqrt(nu * (u_average[0])/ldata.coords[2][0])
    Re_tau.append(u_tau_actual*z_i / nu)
    delta_nu = nu / u_tau_actual

# %%
plt.plot(tt, Re_tau, color='black')

# %% [markdown]
# We could see that the friction Reynolds number is stabilized around 180.

# %% [markdown]
# ## Velocity Validation
#
# Validate the velocity profile with previous research data from {cite}`leeDirectNumericalSimulation2015`. Data can be downloaded from this [link](https://turbulence.oden.utexas.edu/data/MKM/chan180/profiles/chan180.means).

# %%
valid_vf = r'./chan180.means'

# Read in validate velocity
tmp = []
with open(valid_vf, 'r') as f:
    lines = f.readlines()
    for line in lines:
        line = line.replace('\n', '')
        if line.startswith('##'):
            keys = line.split()[1:]
        elif not line.startswith('#'):
            tmp.append([float(d) for d in line.split()])

print(keys)
chan180 = {}
for ind, key in enumerate(keys):
    chan180[key] = np.array(tmp)[:, ind]
# Out:
# ['y', 'y+', 'Umean', 'dUmean/dy', 'Wmean', 'dWmean/dy', 'Pmean']

# %%
fig, ax = plt.subplots(figsize=(6, 4), dpi=150)
ax.scatter(ldata.coords[2]/delta_nu, u_average, marker='x', s = 12, color='black', label='lesgo', alpha=0.7)
ax.plot(chan180['y+'], chan180['Umean'], color='darkcyan', label='chan180', alpha=0.7)
ax.set_xlabel('$z^+$')
ax.set_ylabel('$U^+$')
ax.legend(frameon=False)

# %% [markdown]
# ## Reynolds stress Validation
# Validate the Reynolds stress profile with previous research data from {cite}`leeDirectNumericalSimulation2015`. Data can be downloaded from this [link](https://turbulence.oden.utexas.edu/data/MKM/chan180/profiles/chan180.reystress).

# %% [markdown]
# [Working On]

# %%
ldata.read_data(1)
from pyutils.plot_utils import contour_channel
contour_channel(ldata.coords, ldata.data['theta'][0])
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  [<Axes: xlabel='x', ylabel='y'>,
#   <Axes: xlabel='x', ylabel='z'>,
#   <Axes: xlabel='y', ylabel='z'>])

# %% [markdown]
# ## Temperature Validation
# Validation based on previous literature{cite}`kimTransportPassiveScalars1989`.

# %%
data_f = r'/home/zyou6474/Projects/ERI/notebooks/lesgo/tests/Kim_data.txt'

z_kim = []
T_kim = []
tmp = []
x_tmp = []
with open(data_f) as f:
    lines = f.readlines()
    for line in lines:
        line = line.replace('\n', '')
        if line.startswith('%DATA'):
            if len(tmp)>1: T_kim.append(tmp); z_kim.append(x_tmp)
            tmp = []
            x_tmp = []
            continue
        d = line.split(', ')
        x_tmp.append(float(d[0]))
        tmp.append(float(d[1]))
    T_kim.append(tmp); z_kim.append(x_tmp)

# %% [markdown]
# ### Scalar Normalization
#
# [Working on]

# %%
z_plus = np.empty(shape=(0, len(zc)))
theta_plus = np.empty(shape=(0, theta.shape[2]))
for nk in range(ldata.ntheta):
    theta_bar = np.average(ldata.data['theta'][nk], axis=(0, 1))
    theta_gradient = theta_bar[0]/zc[0]
    print(theta_gradient)
    theta_tau = theta_gradient/RePr[nk]

    z_plus = np.vstack((z_plus, zc*Re))
    theta_plus = np.vstack((theta_plus, theta_bar /theta_tau))
# Out:
# 0.9941429916040561
# 0.9981593157232489
# 0.9985839926178193

# %%
fig, axes = plt.subplots(ldata.ntheta, 1, figsize = (6, 6), dpi=150)
for nk in range(ldata.ntheta):
    axes[nk].scatter(z_plus[nk], theta_plus[nk], s= 12, marker='x', color='navy', alpha=0.5, label='LESGO Pr=%.2f' % Pr_list[nk])
    axes[nk].plot(z_kim[nk], T_kim[nk], linestyle='-.', color='red', alpha=0.5, label='Kim Pr=%.2f' % Pr_list[nk])

    axes[nk].legend(frameon=False)
    axes[nk].set_xlabel('$z^+$')
    axes[nk].set_ylabel('$T^+$')
    axes[nk].set_xscale('log')
    # axes[nk].set_yscale('log')

# %% [markdown]
# # DEBUG
#
# ![](./debug_1.png)
#
# From above picture, we could see that the initial conditions don't satisfy the profile of Kim. Possible reason 1) The way I normalized is wrong. 2) The IC are not satisfied. ( Since larger Prontal number cause the dissipation faster, which is reasonable.).
#
# But the code is still problematic even if the reason is 1) because the flux on the upper boundary is not zero. Check on the test output.

# %%
ldata.read_data(t_ind = 0)
ldata.read_debug(t_ind = 1)
ldata.read_inputs(ldata.inputs_dir)
ldata.data.keys()
# Out:
# dict_keys(['u_ic', 'v_ic', 'w_ic', 'source', 'theta_IC', 'theta_ic', 'u', 'v', 'w', 'theta', 'adv', 'dTdx', 'dTdy', 'dTdz', 'diff', 'u_ihalf', 'v_jhalf', 'w_kw', 'theta_ihalf', 'theta_jhalf', 'theta_kw'])

# %%
import pyutils.plot_utils as pltutils
pltutils.contour_channel(ldata.coords, ldata.data['diff'][0])
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  [<Axes: xlabel='x', ylabel='y'>,
#   <Axes: xlabel='x', ylabel='z'>,
#   <Axes: xlabel='y', ylabel='z'>])

# %% [markdown]
# We could see that the diffusion is almost a linear function in z direction. However, according to Eq.({eq}`theoretical_T`), we know that the diffusion of the IC is a constant in the entire domain, which is -1/RePr. [Fixed]
#
# Now that the profile is almost a constant, however, the lowest one is still not the same as others.

# %%
[plt.plot(ldata.coords[2], ldata.data['diff'][nk, 0, 0, :]*Re_tau[-1]*Pr_list[nk]) for nk in range(ldata.ntheta)]
# Out:
# [[<matplotlib.lines.Line2D at 0x7f702f1f74c0>],
#  [<matplotlib.lines.Line2D at 0x7f702f1f76a0>],
#  [<matplotlib.lines.Line2D at 0x7f702f1f7940>]]

# %% [markdown]
# Check all outputs.

# %%
pltutils.contour_channel(ldata.jhalf_coords, ldata.data['theta_jhalf'][0])
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  [<Axes: xlabel='x', ylabel='y'>,
#   <Axes: xlabel='x', ylabel='z'>,
#   <Axes: xlabel='y', ylabel='z'>])

# %%
plt.plot(ldata.coords[2], ldata.data['dTdz'][nk, 0, 0, :])
plt.plot(ldata.coords[2], np.gradient(ldata.data['theta_IC'][nk, 0, 0, :], ldata.coords[2]))

# %%
from matplotlib import cm
pltutils.contour_channel(ldata.coords, ldata.data['adv'][0], cmap=cm.twilight_shifted)
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  [<Axes: xlabel='x', ylabel='y'>,
#   <Axes: xlabel='x', ylabel='z'>,
#   <Axes: xlabel='y', ylabel='z'>])

# %% [markdown]
# Doesn't looks like very correct since there is some oscillation wave but in the velocity profile there is no oscillation.

# %%
pltutils.contour_channel(ldata.ihalf_coords, ldata.data['u_ihalf'], cmap=cm.turbo)
# Out:
# (<Figure size 800x400 with 4 Axes>,
#  [<Axes: xlabel='x', ylabel='y'>,
#   <Axes: xlabel='x', ylabel='z'>,
#   <Axes: xlabel='y', ylabel='z'>])

# %% [markdown]
# **Velocity Interpolation** Checked.

# %% [markdown]
# Looks like advection has those oscillation.

# %%
plt.contourf(ldata.coords[0], ldata.coords[1], ldata.data['dTdz'][0, :, :, -1].T, cmap=cm.twilight_shifted)
plt.colorbar()

# %% [markdown]
# We could see that the flux on top is not all zero. Need to check on that.

# %% [markdown]
# ### Source
#
# Possible problem: when I add the source, I didn't add the source to entire RHS_T, which might cause problem in solving the tri-diagonal matrix.
