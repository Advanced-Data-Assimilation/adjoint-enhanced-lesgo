# %% [markdown]
# # Full Channel LST

# %%
import numpy as np
import matplotlib.pyplot as plt
from turb.lesgo_utils import lesgo_data, read_array_from_file, write_array_to_file
from pyutils import plot_utils as pltutils
from pyutils.cartesian import meshgrid
from scipy.fft import fft2, ifft2, fft, ifft
from matplotlib import colors, cm

from datetime import datetime
date_marker = datetime.today().strftime('%Y_%m_%d')

# %%
root_dir = '/home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full'

dims = [16, 16, 128]
domain = [2*np.pi, np.pi, 2]

ldata = lesgo_data(domain, dims, root_dir, ntheta=3)

t_total = 1
tstep = 1
tt = np.arange(0, t_total+1, tstep)

# %%
# # Create config template
# ldata._read_lesgoconf('/home/zyou6474/Projects/lesgo_eri/src/lesgo.conf')
# ldata._write_conf('/home/zyou6474/Projects/ERI/notebooks/cases/LST/configs/config_LST_new.ini')

# %%
# Read template config
ldata._read_conf('/home/zyou6474/Projects/ERI/notebooks/cases/LST/configs/config_LST_Full.ini')

# Use parabolic velocity profile as IC
xc, yc, zc = ldata.coords
xx, yy, zz = np.meshgrid(xc, yc, zc, indexing='ij')
ldata.data['u_ic'] = zz * (2-zz)
ldata.data['v_ic'] = zz * 0
ldata.data['w_ic'] = zz * 0

# Create single wavenumber theta in each layer as Initial Condition
# mesh = meshgrid(domain, dims)
thetaic_shape = dims*1
thetaic_shape.insert(0, dims[2])
thetaic_shape = tuple(thetaic_shape)
ldata.data['theta_IC'] = np.empty(shape = thetaic_shape) 
for k in range(dims[2]):
    ldata.data['theta_IC'][k] = 0
    ldata.data['theta_IC'][k, :, :, k] = np.sin(xc)[:, np.newaxis] + yc[np.newaxis, :] *0 

# Switch off Scalar source
ldata.config['SCALAR']['source_opt'] = '0'

ldata.config['SCALAR']['ntheta'] = f'{dims[2]}'

# %%
ldata._fnames(fmt_ntheta='%.3i')
ldata.write_inputs()
ldata._write_conf('/home/zyou6474/Projects/ERI/notebooks/cases/LST/configs/config_LST_Full_%s.ini' % date_marker)
# Out:
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/u_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/v_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/w_velocity.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.001.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.002.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.003.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.004.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.005.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.006.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.007.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.008.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.009.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.010.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.011.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.012.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.013.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.014.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.015.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.016.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.017.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.018.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.019.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.020.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.021.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.022.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.023.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.024.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.025.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.026.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.027.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.028.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.029.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.030.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.031.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.032.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.033.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.034.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.035.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.036.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.037.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.038.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.039.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.040.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.041.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.042.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.043.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.044.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.045.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.046.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.047.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.048.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.049.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.050.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.051.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.052.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.053.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.054.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.055.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.056.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.057.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.058.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.059.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.060.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.061.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.062.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.063.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.064.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.065.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.066.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.067.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.068.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.069.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.070.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.071.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.072.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.073.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.074.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.075.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.076.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.077.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.078.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.079.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.080.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.081.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.082.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.083.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.084.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.085.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.086.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.087.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.088.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.089.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.090.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.091.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.092.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.093.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.094.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.095.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.096.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.097.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.098.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.099.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.100.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.101.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.102.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.103.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.104.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.105.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.106.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.107.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.108.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.109.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.110.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.111.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.112.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.113.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.114.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.115.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.116.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.117.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.118.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.119.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.120.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.121.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.122.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.123.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.124.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.125.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.126.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.127.IC
# write data into /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/theta.128.IC
# Write configs in /home/zyou6474/Projects/lesgo_adjoint_tutorial_bundle/tests/61_LST_Full/inputs/lesgo.conf
# Configs is written in /home/zyou6474/Projects/ERI/notebooks/cases/LST/configs/config_LST_Full_2023_09_02.ini

# %%
# Check theta ICs
k = 1
plt.contourf(ldata.data['theta_IC'][k, :, :, k].T, norm = colors.Normalize(-1, 1), cmap = cm.twilight_shifted, levels=50)
plt.colorbar()

# %% [markdown]
# ## LST
# [Reference ???]
#
# $$
# A\hat{T}_{t=0}^{kx=1, ky=0} = \hat{T}_{t=1}^{kx=1, ky=0}
# $$

# %%
ic_field = ldata.data['theta_IC'][k, :, :, k]
coef_ic = fft2(ic_field)
print(coef_ic)
kx, ky = np.unravel_index(np.real(coef_ic).argmax(), (dims[0], dims[1]))
print(kx, ky, coef_ic[kx, ky])
# Out:
# [[-4.44089210e-16-0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 2.49715612e+01-1.25540516e+02j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-8.34301364e-16-6.59438833e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-2.66453526e-15-1.47158219e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 1.77635684e-15-5.77315973e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-8.88178420e-16-6.21724894e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-2.71841231e-15-6.59438833e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 2.84217094e-14-2.13162821e-14j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-1.02140518e-14-0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 2.84217094e-14+2.13162821e-14j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-2.71841231e-15+6.59438833e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-8.88178420e-16+6.21724894e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 1.77635684e-15+5.77315973e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-2.66453526e-15+1.47158219e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [-8.34301364e-16+6.59438833e-15j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]
#  [ 2.49715612e+01+1.25540516e+02j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j
#    0.00000000e+00-0.00000000e+00j  0.00000000e+00-0.00000000e+00j]]
# 1 0 (24.9715612180644-125.5405158916135j)

# %%
kx = 1
ky = 0
coef_ic[kx, ky]
# Out:
# (24.9715612180644-125.5405158916135j)

# %%
ldata._fnames(fmt_ntheta='%.3i')
ldata.read_data(1)

# %%
k = 1
plt.contourf(ldata.data['theta'][k, :, :, k].T, norm = colors.Normalize(-1, 1), cmap = cm.twilight_shifted, levels=50)
plt.colorbar()

# %%
B = []
for nk in range(ldata.ntheta):
    for k in range(ldata.dims[2]):
      B.append(fft2(ldata.data['theta'][nk, :, :, k])[kx, ky])
      
B = np.reshape(np.array(B), (ldata.ntheta, ldata.dims[2]))
print(B)
# Out:
# [[2.48406822e+01-1.24882572e+02j 4.19919933e-02-2.11108057e-01j
#   6.80580924e-05-3.42151217e-04j ... 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [4.28901718e-02-2.15623611e-01j 2.48881392e+01-1.25121216e+02j
#   4.03371962e-02-2.02788926e-01j ... 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [7.09970179e-05-3.56926546e-04j 4.11978686e-02-2.07115924e-01j
#   2.48915595e+01-1.25138472e+02j ... 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  ...
#  [0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j ... 2.49684861e+01-1.25525857e+02j
#   1.45920896e-03-7.33598563e-03j 8.52255814e-08-4.28460664e-07j]
#  [0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j ... 1.46001410e-03-7.34001503e-03j
#   2.49685494e+01-1.25525861e+02j 1.45829637e-03-7.33137939e-03j]
#  [0.00000000e+00+0.00000000e+00j 0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j ... 8.52962395e-08-4.28813715e-07j
#   1.45870054e-03-7.33339246e-03j 2.49700707e+01-1.25533187e+02j]]

# %%
I = np.identity(ldata.ntheta) * coef_ic[kx, ky]
A = B @ np.linalg.inv(I)
print( A)
# Out:
# [[ 9.94759106e-01-4.55466876e-08j  1.68159302e-03-7.69945120e-11j
#    2.72542463e-06-1.24788065e-13j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 1.71756188e-03-2.37874477e-10j  9.96660012e-01-1.38032860e-07j
#    1.61532649e-03-2.23715342e-10j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 2.84311823e-06-6.61665358e-13j  1.64979340e-03-3.83948556e-10j
#    9.96797452e-01-2.31979921e-07j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  ...
#  [-0.00000000e+00+0.00000000e+00j -0.00000000e+00+0.00000000e+00j
#   -0.00000000e+00+0.00000000e+00j ...  9.99882991e-01-1.22034086e-06j
#    5.84351896e-05-7.13191947e-11j  3.41292655e-09-4.16542113e-15j]
#  [-0.00000000e+00+0.00000000e+00j -0.00000000e+00+0.00000000e+00j
#   -0.00000000e+00+0.00000000e+00j ...  5.84672916e-05-4.33954994e-11j
#    9.99883119e-01-7.42131646e-07j  5.83985039e-05-4.33444439e-11j]
#  [-0.00000000e+00+0.00000000e+00j -0.00000000e+00+0.00000000e+00j
#   -0.00000000e+00+0.00000000e+00j ...  3.41573946e-09-8.56309271e-16j
#    5.84145448e-05-1.46442423e-11j  9.99941570e-01-2.50680489e-07j]]

# %%
eig, eigv = np.linalg.eig(A)

# %%
from scipy.io import loadmat
mat_f = r'./data/LST_template.mat'
mat_data = loadmat(mat_f)

mat_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'A', 'B', 'Temperature', 'omega', 'y_phys'])

# %%
# from scipy.io import loadmat
# lesgo_f = r'./data/lesgo.mat'
# lesgo_vars = loadmat(lesgo_f)
# print(lesgo_vars.keys())
# eig = lesgo_vars['lambda'][:, 0]
# eigv = lesgo_vars['lesgo_v']

# %%
lst = np.log(eig)/1e-5/1j * -1

# %%
fig, ax = plt.subplots()
ax.scatter(np.real(lst), np.imag(lst), s= 12, marker='x', color='black', alpha=0.5, label='lesgo')
# ax.set_xlim(-0.1, 1.1)
ax.set_title(r'$\omega$')
fig.savefig('./imgs/omega.png',  bbox_inches='tight')

# %%
lesgo_indset = [68, 69]
lst_indset = [119, 144]


for ind, _ in enumerate(lesgo_indset):
    fig, ax = plt.subplots()
    
    scatter_set = []
    scatter_set.append(ax.scatter(np.real(lst), np.imag(lst), s= 12, marker='x', color='black', alpha=0.5, label='lesgo'))
    scatter_set.append(ax.scatter(np.real(mat_data['omega']), np.imag(mat_data['omega']), marker='x', color='orange', alpha=0.3, label='LST'))
    # scatter_set.append(ax.scatter(np.real(mat_data['omega'][120, 0]), np.imag(mat_data['omega'][120, 0]), marker='x', color='indianred', label='LST discrete'))
    # scatter_set.append([ax.scatter(np.real(mat_data['omega'][ind, 0]), np.imag(mat_data['omega'][ind, 0]), s= 50, marker='x', color='indianred', label='LST boundary') for ind in lst_indset][0])
    # scatter_set.append([ax.scatter(np.real(lst[ind]), np.imag(lst[ind]), s= 50, marker='x', color='navy', alpha=0.5, label='lesgo boundary') for ind in lesgo_indset][0])
    scatter_set.append(ax.scatter(np.real(mat_data['omega'][lst_indset[ind], 0]), np.imag(mat_data['omega'][lst_indset[ind], 0]), s= 50, marker='x', color='indianred', label='LST point'))
    scatter_set.append(ax.scatter(np.real(lst[lesgo_indset[ind]]), np.imag(lst[lesgo_indset[ind]]), s= 50, marker='x', color='g', alpha=0.5, label='lesgo point'))

    ax.set_ylim(-10, 1)
    ax.set_xlim(0.4, 1)

    labs = [l.get_label() for l in scatter_set]
    ax.legend(scatter_set, labs, loc=0)
    fig.savefig('./imgs/full_omega_lesgo%.3i_LST%.3i.png' %(lesgo_indset[ind], lst_indset[ind]), bbox_inches='tight')

# %%
lst_indset = np.argwhere(np.imag(mat_data['omega'][:, 0])>-0.3)
print(lst_indset)
mat_data['omega'][np.imag(mat_data['omega'][:, 0])>-0.3, 0]
# Out:
# [[  3]
#  [  8]
#  [ 19]
#  [ 59]
#  [ 60]
#  [ 89]
#  [ 90]
#  [119]
#  [120]
#  [144]
#  [145]]
# array([0.43689419-0.12350871j, 0.74182772-0.25251338j,
#        0.69650517-0.17349471j, 0.95100985-0.05024926j,
#        0.61755299-0.27288752j, 0.83786341-0.16007931j,
#        0.52480465-0.2964694j , 0.92337223-0.07462662j,
#        0.61500598-0.20821216j, 0.5980823 -0.2379818j ,
#        0.80321021-0.28096161j])

# %%
lesgo_indset = np.argwhere(np.imag(lst)>-0.3)
print(lesgo_indset)
lst[np.imag(lst)>-0.3]
# Out:
# [[68]
#  [69]
#  [70]
#  [71]
#  [72]
#  [77]]
# array([0.93084273-0.04644669j, 0.84359439-0.13380795j,
#        0.47591933-0.24673107j, 0.75648897-0.22143381j,
#        0.65686684-0.29957198j, 0.21131374-0.11728661j])

# %%
y_phys = np.cos(np.linspace(0, np.pi, 384))

# %%
x = np.linspace(0, 1, 100)
dx = x[-1] - x[-2::-1]
x = np.append(x, x[-1] + dx)
x.shape
x
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#        0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#        0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#        0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
#        0.70707071, 0.71717172, 0.72727273, 0.73737374, 0.74747475,
#        0.75757576, 0.76767677, 0.77777778, 0.78787879, 0.7979798 ,
#        0.80808081, 0.81818182, 0.82828283, 0.83838384, 0.84848485,
#        0.85858586, 0.86868687, 0.87878788, 0.88888889, 0.8989899 ,
#        0.90909091, 0.91919192, 0.92929293, 0.93939394, 0.94949495,
#        0.95959596, 0.96969697, 0.97979798, 0.98989899, 1.        ,
#        1.01010101, 1.02020202, 1.03030303, 1.04040404, 1.05050505,
#        1.06060606, 1.07070707, 1.08080808, 1.09090909, 1.1010101 ,
#        1.11111111, 1.12121212, 1.13131313, 1.14141414, 1.15151515,
#        1.16161616, 1.17171717, 1.18181818, 1.19191919, 1.2020202 ,
#        1.21212121, 1.22222222, 1.23232323, 1.24242424, 1.25252525,
#        1.26262626, 1.27272727, 1.28282828, 1.29292929, 1.3030303 ,
#        1.31313131, 1.32323232, 1.33333333, 1.34343434, 1.35353535,
#        1.36363636, 1.37373737, 1.38383838, 1.39393939, 1.4040404 ,
#        1.41414141, 1.42424242, 1.43434343, 1.44444444, 1.45454545,
#        1.46464646, 1.47474747, 1.48484848, 1.49494949, 1.50505051,
#        1.51515152, 1.52525253, 1.53535354, 1.54545455, 1.55555556,
#        1.56565657, 1.57575758, 1.58585859, 1.5959596 , 1.60606061,
#        1.61616162, 1.62626263, 1.63636364, 1.64646465, 1.65656566,
#        1.66666667, 1.67676768, 1.68686869, 1.6969697 , 1.70707071,
#        1.71717172, 1.72727273, 1.73737374, 1.74747475, 1.75757576,
#        1.76767677, 1.77777778, 1.78787879, 1.7979798 , 1.80808081,
#        1.81818182, 1.82828283, 1.83838384, 1.84848485, 1.85858586,
#        1.86868687, 1.87878788, 1.88888889, 1.8989899 , 1.90909091,
#        1.91919192, 1.92929293, 1.93939394, 1.94949495, 1.95959596,
#        1.96969697, 1.97979798, 1.98989899, 2.        ])

# %%
ind = lesgo_indset[0]
LST_ind = lst_indset[-4]
print(ind, LST_ind)

fig, ax = plt.subplots()
ax1 = ax.twiny()
# ax.plot(zc, eigv[:, ind], color='navy', linestyle='-.')
ax.plot(zc, np.abs(eigv[:, ind])/np.max(np.abs(eigv[:, ind])), color='navy', linestyle='-.')
ax.set_xlabel(f'lesgo {lst[ind]}', color='navy')

ax1.plot(y_phys, np.abs(mat_data['Temperature'][:, LST_ind])/np.max(np.abs(mat_data['Temperature'][:, LST_ind])), color='indianred',)
ax1.set_xlabel(f'LST %s' % str(mat_data['omega'][LST_ind, 0]), color='indianred')

ax.set_title('eigen-mode comparison')
ax.legend()
fig.savefig('./imgs/full_one_wave.png', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [68] [119]

# %%
ind = lesgo_indset[1]
LST_ind = lst_indset[-2]
print(ind, LST_ind)

fig, ax = plt.subplots()
ax1 = ax.twiny()
# ax.plot(zc, eigv[:, ind], color='navy', linestyle='-.')
ax.plot(zc, np.abs(eigv[:, ind])/np.max(np.abs(eigv[:, ind])), color='navy', linestyle='-.')
ax.set_xlabel(f'lesgo {lst[ind]}', color='navy')

ax1.plot(y_phys, np.abs(mat_data['Temperature'][:, LST_ind])/np.max(np.abs(mat_data['Temperature'][:, LST_ind])), color='indianred',)
ax1.set_xlabel(f'LST %s' % str(mat_data['omega'][LST_ind, 0]), color='indianred')

ax.set_title('eigen-mode comparison')
ax.legend()
fig.savefig('./imgs/full_two_wave.png', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [69] [144]

# %%
ind = lesgo_indset[2]
LST_ind = lst_indset[-4]
print(ind, LST_ind)

fig, ax = plt.subplots()
ax1 = ax.twiny()
# ax.plot(zc, eigv[:, ind], color='navy', linestyle='-.')
ax.plot(zc, np.abs(eigv[:, ind])/np.max(np.abs(eigv[:, ind])), color='navy', linestyle='-.')
ax.set_xlabel(f'lesgo {lst[ind]}', color='navy')

ax1.plot(y_phys, np.abs(mat_data['Temperature'][:, LST_ind])/np.max(np.abs(mat_data['Temperature'][:, LST_ind])), color='indianred',)
ax1.set_xlabel(f'LST %s' % str(mat_data['omega'][LST_ind, 0]), color='indianred')

ax.set_title('eigen-mode comparison')
ax.legend()
fig.savefig('./imgs/full_one_wave2.png', bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [70] [119]
